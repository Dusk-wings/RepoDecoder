# %%
import sys
from pathlib import Path

BACKEND_PATH = "/home/user/Documents/Project_5/backend"
# Adds the parent 'backend' directory to sys.path
if BACKEND_PATH not in sys.path:
    sys.path.append(BACKEND_PATH)

# %%
from app.rag.parser.markdown_parser import MarkDownParser
from app.rag.chunker.markdown_chunker import MarkdownChunker
from app.rag.parser.parser import Parser
from app.rag.embedder.embedder import Embedder

# %%
parser = Parser()
md_chunker = MarkdownChunker(
    file_path=Path(
        "/home/user/Documents/Project_5/backend/experiments/data/code/documents/test.md"
    ),
    ext_lang_name=parser.extension_to_language_name
)
md_parser = MarkDownParser()
embedder = Embedder()

# %%
parsed_md = md_parser.parser(
    file_path=Path(
        "/home/user/Documents/Project_5/backend/experiments/data/code/palindrome.md"
    ),
    doc=None,
)
if parsed_md:
    parser._set_file_path(
        file_path=Path(
            "/home/user/Documents/Project_5/backend/experiments/data/code/palindrome.md"
        )
    )
    chunks = md_chunker.create_md_embedding_content(
        chunks=parsed_md, optimize=True, count_token=embedder.count_tokens
    )

# %%
print(chunks)
# Out:
# [{'chunk': {'content': '## Cpp Programming language', 'token_count': 57, 'metadata': {'headings': {2: '## Cpp Programming language\n'}, 'sections_covered': {'h1': [], 'h2': ['## Cpp Programming language\n']}, 'is_image': False, 'is_table': False, 'contains_code_block': True}}, 'embedding_str': 'File: /home/user/Documents/Project_5/backend/experiments/data/code/documents/test.md\n\nLanguage: markdown\n\nContent type: code\n\nSection context:\nH2: ## Cpp Programming language\n\nSections covered:\nH2: ## Cpp Programming language\n\nContent:\n## Cpp Programming language'}, {'chunk': {'content': 'A code example of the cpp code that is writen up over here and a lot of lorem ipsum next to it, lorem ipsum dolor sit amet consectetur adipiscing elit reprehenderit assumenda nam elit culpa quo aut dolores officia blanditiis tempor imperdiet quo autem iusto proident dolore deserunt ex expedita officia excepteur dolores nam voluptate est dignissimos similique dolores vel est commodo nam voluptatum
# ...

# %%
[
    {
        "chunk": {
            "content": "## Cpp Programming language",
            "token_count": 57,
            "metadata": {
                "headings": {2: "## Cpp Programming language\n"},
                "sections_covered": {"h1": [], "h2": ["## Cpp Programming language\n"]},
                "is_image": False,
                "is_table": False,
                "contains_code_block": True,
            },
        },
        "embedding_str": "File: /home/user/Documents/Project_5/backend/experiments/data/code/documents/test.md\n\nLanguage: markdown\n\nContent type: code\n\nSection context:\nH2: ## Cpp Programming language\n\nSections covered:\nH2: ## Cpp Programming language\n\nContent:\n## Cpp Programming language",
    },
    {
        "chunk": {
            "content": "A code example of the cpp code that is writen up over here and a lot of lorem ipsum next to it, lorem ipsum dolor sit amet consectetur adipiscing elit reprehenderit assumenda nam elit culpa quo aut dolores officia blanditiis tempor imperdiet quo autem iusto proident dolore deserunt ex expedita officia excepteur dolores nam voluptate est dignissimos similique dolores vel est commodo nam voluptatum in qui occaecat sint nam incididunt ut provident ex maxime laborum pariatur et consequatur quas veniam soluta nulla fugiat amet est cum autem culpa at ut irure dolorum mollitia nihil cupiditate nostrud qui ea sed optio voluptas autem cum voluptas repellendus pariatur est nulla temporibus omnis maxime dolor placeat nihil est libero temporibus et amet nisi harum adipiscing dolore autem id consequat ut nostrud soluta officia id enim laborum mollit occaecat eum nihil quo iusto mollit quod voluptatum dignissimos ullamco sed eligendi autem omnis tempore proident esse nostrud dolore est eos illum quibusdam at facilis deserunt distinctio eiusmod voluptate nobis ut quod possimus fuga qui ut voluptas quod voluptatum quo autem quibusdam nisi id odio commodo irure eligendi consequatur laborum in dolore cupidatat",
            "token_count": 449,
            "metadata": {
                "headings": {2: "## Cpp Programming language\n"},
                "sections_covered": {"h1": [], "h2": ["## Cpp Programming language\n"]},
                "is_image": False,
                "is_table": False,
                "contains_code_block": True,
            },
        },
        "embedding_str": "File: /home/user/Documents/Project_5/backend/experiments/data/code/documents/test.md\n\nLanguage: markdown\n\nContent type: code\n\nSection context:\nH2: ## Cpp Programming language\n\nSections covered:\nH2: ## Cpp Programming language\n\nContent:\nA code example of the cpp code that is writen up over here and a lot of lorem ipsum next to it, lorem ipsum dolor sit amet consectetur adipiscing elit reprehenderit assumenda nam elit culpa quo aut dolores officia blanditiis tempor imperdiet quo autem iusto proident dolore deserunt ex expedita officia excepteur dolores nam voluptate est dignissimos similique dolores vel est commodo nam voluptatum in qui occaecat sint nam incididunt ut provident ex maxime laborum pariatur et consequatur quas veniam soluta nulla fugiat amet est cum autem culpa at ut irure dolorum mollitia nihil cupiditate nostrud qui ea sed optio voluptas autem cum voluptas repellendus pariatur est nulla temporibus omnis maxime dolor placeat nihil est libero temporibus et amet nisi harum adipiscing dolore autem id consequat ut nostrud soluta officia id enim laborum mollit occaecat eum nihil quo iusto mollit quod voluptatum dignissimos ullamco sed eligendi autem omnis tempore proident esse nostrud dolore est eos illum quibusdam at facilis deserunt distinctio eiusmod voluptate nobis ut quod possimus fuga qui ut voluptas quod voluptatum quo autem quibusdam nisi id odio commodo irure eligendi consequatur laborum in dolore cupidatat",
    },
    {
        "chunk": {
            "content": "fuga qui ut voluptas quod voluptatum quo autem quibusdam nisi id odio commodo irure eligendi consequatur laborum in dolore cupidatat illum exercitation voluptas accusamus harum dolor aliqua qui aute omnis nulla pariatur dolor et magna aut ipsum nobis qui consequat soluta adipiscing animi rerum libero duis id ad et velit temporibus adipiscing quibusdam dolor consequat nihil eligendi nisi nobis pariatur et dignissimos expedita dolores eos deserunt quo dolor cumque tempore officia ad minus dolores ea assumenda irure distinctio accusamus laboris eu sit et minim esse quo deleniti autem similique irure proident molestias excepturi mollit voluptas id ex voluptate nobis nulla illum esse ducimus quo occaecat id officia dolorum quibusdam exercitation ducimus proident eligendi est blanditiis quidem maxime at ad eiusmod cupidatat dolore autem qui excepteur est est quo eiusmod labore praesentium laborum non omnis culpa eos eum commodo ut reprehenderit dolore eu dolor commodo enim soluta in minim esse sit sint et dolor amet ad similique do anim excepturi quidem excepteur officia ex dolor odio eligendi duis imperdiet eiusmod nulla ullamco quo facere excepturi sit qui quo dolore et laboris eum tempore imperdiet illum aute dolores est est",
            "token_count": 450,
            "metadata": {
                "headings": {2: "## Cpp Programming language\n"},
                "sections_covered": {"h1": [], "h2": ["## Cpp Programming language\n"]},
                "is_image": False,
                "is_table": False,
                "contains_code_block": True,
            },
        },
        "embedding_str": "File: /home/user/Documents/Project_5/backend/experiments/data/code/documents/test.md\n\nLanguage: markdown\n\nContent type: code\n\nSection context:\nH2: ## Cpp Programming language\n\nSections covered:\nH2: ## Cpp Programming language\n\nContent:\nfuga qui ut voluptas quod voluptatum quo autem quibusdam nisi id odio commodo irure eligendi consequatur laborum in dolore cupidatat illum exercitation voluptas accusamus harum dolor aliqua qui aute omnis nulla pariatur dolor et magna aut ipsum nobis qui consequat soluta adipiscing animi rerum libero duis id ad et velit temporibus adipiscing quibusdam dolor consequat nihil eligendi nisi nobis pariatur et dignissimos expedita dolores eos deserunt quo dolor cumque tempore officia ad minus dolores ea assumenda irure distinctio accusamus laboris eu sit et minim esse quo deleniti autem similique irure proident molestias excepturi mollit voluptas id ex voluptate nobis nulla illum esse ducimus quo occaecat id officia dolorum quibusdam exercitation ducimus proident eligendi est blanditiis quidem maxime at ad eiusmod cupidatat dolore autem qui excepteur est est quo eiusmod labore praesentium laborum non omnis culpa eos eum commodo ut reprehenderit dolore eu dolor commodo enim soluta in minim esse sit sint et dolor amet ad similique do anim excepturi quidem excepteur officia ex dolor odio eligendi duis imperdiet eiusmod nulla ullamco quo facere excepturi sit qui quo dolore et laboris eum tempore imperdiet illum aute dolores est est",
    },
    {
        "chunk": {
            "content": "eiusmod nulla ullamco quo facere excepturi sit qui quo dolore et laboris eum tempore imperdiet illum aute dolores est est ea nulla eum atque consequat mollit excepturi sint dolorem quo dolore nisi dolore minus id consequatur et labore tempore minus ducimus culpa pariatur lorem sunt voluptas pariatur soluta id est sint sunt eum vel mollit animi ut molestias exercitation dolorem fugiat libero nobis qui est corrupti omnis et ut optio vero odio sunt dolorum non blanditiis nulla iusto dolore eum eu omnis et fuga nulla sunt dignissimos cumque sed tempor amet blanditiis aliquip ad occaecat eiusmod consectetur cupidatat sint velit quis omnis eos est est facilis placeat in vel irure culpa commodo expedita anim quibusdam expedita soluta quo dolores cillum voluptatum maxime eligendi dolore irure cumque libero culpa illum velit at deserunt qui veniam commodo excepteur cupidatat molestias eum repellendus eum nostrud repellendus eos dolorum quo et nulla in nobis fuga quo corrupti facere atque anim occaecat elit sed adipiscing in cupidatat labore nobis animi soluta omnis dolore veniam distinctio qui vero provident nulla eu tempore quod anim reprehenderit ipsum omnis repellendus",
            "token_count": 449,
            "metadata": {
                "headings": {2: "## Cpp Programming language\n"},
                "sections_covered": {"h1": [], "h2": ["## Cpp Programming language\n"]},
                "is_image": False,
                "is_table": False,
                "contains_code_block": True,
            },
        },
        "embedding_str": "File: /home/user/Documents/Project_5/backend/experiments/data/code/documents/test.md\n\nLanguage: markdown\n\nContent type: code\n\nSection context:\nH2: ## Cpp Programming language\n\nSections covered:\nH2: ## Cpp Programming language\n\nContent:\neiusmod nulla ullamco quo facere excepturi sit qui quo dolore et laboris eum tempore imperdiet illum aute dolores est est ea nulla eum atque consequat mollit excepturi sint dolorem quo dolore nisi dolore minus id consequatur et labore tempore minus ducimus culpa pariatur lorem sunt voluptas pariatur soluta id est sint sunt eum vel mollit animi ut molestias exercitation dolorem fugiat libero nobis qui est corrupti omnis et ut optio vero odio sunt dolorum non blanditiis nulla iusto dolore eum eu omnis et fuga nulla sunt dignissimos cumque sed tempor amet blanditiis aliquip ad occaecat eiusmod consectetur cupidatat sint velit quis omnis eos est est facilis placeat in vel irure culpa commodo expedita anim quibusdam expedita soluta quo dolores cillum voluptatum maxime eligendi dolore irure cumque libero culpa illum velit at deserunt qui veniam commodo excepteur cupidatat molestias eum repellendus eum nostrud repellendus eos dolorum quo et nulla in nobis fuga quo corrupti facere atque anim occaecat elit sed adipiscing in cupidatat labore nobis animi soluta omnis dolore veniam distinctio qui vero provident nulla eu tempore quod anim reprehenderit ipsum omnis repellendus",
    },
    {
        "chunk": {
            "content": 'labore nobis animi soluta omnis dolore veniam distinctio qui vero provident nulla eu tempore quod anim reprehenderit ipsum omnis repellendus exercitation esse in nobis cumque\n\n```cpp\nusing System;\n\nclass Palindrome\n{\n    static void Main()\n    {\n        int num = 121;\n        int n = num;\n        int reversed = 0;\n\nwhile (n > 0)\n        {\n            int digit = n % 10;\n            reversed = reversed * 10 + digit;\n            n = n / 10;\n        }\n\nif (num == reversed)\n        {\n            Console.WriteLine(num + " is a palindrome");\n        }\n        else\n        {\n            Console.WriteLine(num + " is not a palindrome");\n        }\n    }\n}\n```',
            "token_count": 282,
            "metadata": {
                "headings": {2: "## Cpp Programming language\n"},
                "sections_covered": {"h1": [], "h2": ["## Cpp Programming language\n"]},
                "is_image": False,
                "is_table": False,
                "contains_code_block": True,
            },
        },
        "embedding_str": 'File: /home/user/Documents/Project_5/backend/experiments/data/code/documents/test.md\n\nLanguage: markdown\n\nContent type: code\n\nSection context:\nH2: ## Cpp Programming language\n\nSections covered:\nH2: ## Cpp Programming language\n\nContent:\nlabore nobis animi soluta omnis dolore veniam distinctio qui vero provident nulla eu tempore quod anim reprehenderit ipsum omnis repellendus exercitation esse in nobis cumque\n\n```cpp\nusing System;\n\nclass Palindrome\n{\n    static void Main()\n    {\n        int num = 121;\n        int n = num;\n        int reversed = 0;\n\nwhile (n > 0)\n        {\n            int digit = n % 10;\n            reversed = reversed * 10 + digit;\n            n = n / 10;\n        }\n\nif (num == reversed)\n        {\n            Console.WriteLine(num + " is a palindrome");\n        }\n        else\n        {\n            Console.WriteLine(num + " is not a palindrome");\n        }\n    }\n}\n```',
    },
    {
        "chunk": {
            "metadata": {
                "headings": {2: "## A random code image\n"},
                "is_image": True,
                "is_code_block": False,
                "is_table": False,
                "image": {
                    "image_urls": ["image.jpg"],
                    "alt_texts": ["Random Code"],
                    "descriptions": [
                        "This image displays a serene, stylized nighttime scene rendered in a 2D animation style. A large, pale full moon with subtle craters dominates the upper portion of the frame, casting a soft glow over a dense forest of sharply pointed evergreen trees. The trees are silhouetted in dark blue and gray tones, their layered branches creating a textured foreground that recedes into the distance. The sky is a gradient of deep teal to lighter blue, scattered with small, bright white stars. The overall atmosphere is calm and slightly melancholic. The composition is horizontal, focusing on the contrast between the luminous moon and the shadowy treeline. The art style is simple yet effective, using clear lines and flat colors to evoke a peaceful winter night."
                    ],
                },
            },
            "content": "## A random code image\n\n\nThis image displays a serene, stylized nighttime scene rendered in a 2D animation style. A large, pale full moon with subtle craters dominates the upper portion of the frame, casting a soft glow over a dense forest of sharply pointed evergreen trees. The trees are silhouetted in dark blue and gray tones, their layered branches creating a textured foreground that recedes into the distance. The sky is a gradient of deep teal to lighter blue, scattered with small, bright white stars. The overall atmosphere is calm and slightly melancholic. The composition is horizontal, focusing on the contrast between the luminous moon and the shadowy treeline. The art style is simple yet effective, using clear lines and flat colors to evoke a peaceful winter night.",
            "token_count": 211,
        },
        "embedding_str": "File: /home/user/Documents/Project_5/backend/experiments/data/code/documents/test.md\n\nLanguage: markdown\n\nContent type: image\n\nSection context:\nH2: ## A random code image\n\nImage descriptions:\nRandom Code\n\nContent:\n## A random code image\n\n\nThis image displays a serene, stylized nighttime scene rendered in a 2D animation style. A large, pale full moon with subtle craters dominates the upper portion of the frame, casting a soft glow over a dense forest of sharply pointed evergreen trees. The trees are silhouetted in dark blue and gray tones, their layered branches creating a textured foreground that recedes into the distance. The sky is a gradient of deep teal to lighter blue, scattered with small, bright white stars. The overall atmosphere is calm and slightly melancholic. The composition is horizontal, focusing on the contrast between the luminous moon and the shadowy treeline. The art style is simple yet effective, using clear lines and flat colors to evoke a peaceful winter night.",
    },
]

# %%
from app.rag.parser.pdf_parser import PdfParser

# %%
pd_parser = PdfParser(repo_root=Path("/home/user/Documents/Project_5/backend/experiments/data/code/documents"))

# %%
converted = pd_parser.convert_file(
    file_path=Path(
        "/home/user/Documents/Project_5/backend/experiments/data/code/documents/nolen.pdf"
    )
)
# Out:
# Loading weights: 100%|██████████| 770/770 [00:00<00:00, 2564.20it/s]

# %%
print(converted)
# Out:
# /home/user/Documents/Project_5/backend/experiments/data/code/documents/output/nolen.md

# %%
parser = Parser()
md_chunker = MarkdownChunker(
    file_path=Path(
        converted
    ),
    ext_lang_name=parser.extension_to_language_name
)
md_parser = MarkDownParser()
embedder = Embedder()

# %%
parsed_md = md_parser.parser(
    file_path=Path(
        converted
    ),
    doc=None,
    use_vision_llm=False
)

# %%
if parsed_md:
    parser._set_file_path(
        file_path=Path(
            converted
        )
    )
    chunks = md_chunker.create_md_embedding_content(
        chunks=parsed_md, optimize=True, count_token=embedder.count_tokens
    )

# %%
print(chunks)
# Out:
# [{'chunk': {'content': "## Christopher Nolan: A Visionary Filmmaker and His Filmography\n\n## Introduction\n\n\nChristopher Edward Nolan is one of the most influential filmmakers of the twenty-first century. Born in London on July 30, 1970, Nolan developed an interest in filmmaking from childhood and began making short films with a Super 8 camera at the age of seven. He later studied English literature at University College London, where he became involved with the university's film society. His early experiences making films with limited resources helped shape the practical, independent approach that would characterize his career.\n\n\nNolan is particularly known for combining large-scale cinematic spectacle with intellectually demanding stories. His films frequently explore memory, time, identity, dreams, morality, fate, and the limits of human knowledge. Rather than treating the audience as passive viewers, he often constructs narratives that require them to piece together events 
# ...

# %%
from rag.parser.document_parser import DocumentParser

# %%
doc_parser = DocumentParser()

# %%
doc_file_path = Path("/home/user/Documents/Project_5/backend/experiments/data/code/documents/test.pptx")

# %%
parsed_doc = doc_parser.parse(filepath=doc_file_path)
# Out:
# [System] Converting .pptx to Markdown via Pandoc...

# %%
print(parsed_doc)
# Out:
# ## This is the slide a PPTX slide
#
# Don't dare and fuck you if you try to delete it it should state how it is
#
# ## This is the image content of this file
#
# ![](temp_media/ppt/media/image1.png)
#
# ## This is the table
#
#   1   Delhi         New Delhi   India   110001
#   --- ------------- ----------- ------- --------
#   2   Maharashtra   Mumbai      India   400001
#   3   Tamil Nadu    Chennai     India   600001
#   4   Arunachal     Itanagar    India   791111
#
# ## This is Chart
#
#
#
# ### [Chart Data: Popullation Chart
# A chart showing popullation for 3 years  (Slide 4)]
# | Category | Column 1 | Column 2 | Column 3 |
# |---| --- | --- | --- |
# | Row 1 | 9.1 | 3.2 | 4.54 |
# | Row 2 | 2.4 | 8.8 | 9.65 |
# | Row 3 | 3.1 | 1.5 | 3.7 |
# | Row 4 | 4.3 | 9.02 | 6.2 |
#
#
# ## This is the fifth slide
#
# - Content floating around
#
# ![](temp_media/ppt/media/image1.png)

# %%
md_chunker = MarkdownChunker(
    file_path=doc_file_path,
    ext_lang_name=parser.extension_to_language_name,
    # overlap_chunks=1
)
parsed_markdown = md_parser.parser(doc=parsed_doc, file_path=None)
if parsed_markdown:
    parser._set_file_path(file_path=doc_file_path)
    chunks = md_chunker.create_md_embedding_content(
        chunks=parsed_markdown,
        optimize=True,
        count_token=embedder.count_tokens,
    )
    doc_parser.delete_converted_doc()

# %%
chunks
# Out:
# [{'chunk': {'content': "## This is the slide a PPTX slide\n\n\nDon't dare and fuck you if you try to delete it it should state how it is",
#    'token_count': 88,
#    'metadata': {'headings': {2: '## This is the slide a PPTX slide\n'},
#     'sections_covered': {'h1': [],
#      'h2': ['## This is the slide a PPTX slide\n']},
#     'is_image': False,
#     'is_table': False,
#     'contains_code_block': False}},
#   'embedding_str': "File: /home/user/Documents/Project_5/backend/experiments/data/code/documents/test.pptx\n\nLanguage: unknown\n\nContent type: text\n\nSection context:\nH2: ## This is the slide a PPTX slide\n\nSections covered:\nH2: ## This is the slide a PPTX slide\n\nContent:\n## This is the slide a PPTX slide\n\n\nDon't dare and fuck you if you try to delete it it should state how it is"},
#  {'chunk': {'metadata': {'headings': {2: '## This is the image content of this file\n'},
#     'is_image': True,
#     'is_code_block': False,
#     'is_table': False,
# ...
