# %%
from rag.parser.import_parser import ImportParser
from pathlib import Path

# %%
import_parser = ImportParser(root_path=Path("/home/user/Documents/Project_5/backend/experiments/data/code/bank_py"))

# %%
print(
    import_parser.extract_imports(
        Path(
            "/home/user/Documents/Project_5/backend/experiments/data/code/bank_py/main.py"
        ),
        root_path=Path(
            "/home/user/Documents/Project_5/backend/experiments/data/code/bank_py"
        ),
    )
)
# Out:
# Node Type :  import_from_statement Text :  from savings_account import SavingsAccount, sayWhat, sayWhy
# Node Type :  import_from_statement Text :  from checking_account import CheckingAccount as cb
# Node Type :  import_from_statement Text :  from checking_account import *
# Node Type :  import_from_statement Text :  from os import mkdir
# Node Type :  import_statement Text :  import math as m, os
# Node Type :  import_statement Text :  import bank_account
# Node Type :  import_statement Text :  import http
# Node Type :  import_from_statement Text :  from fastapi import FastAPI
# Node Type :  import_statement Text :  import importlib
# Node Type :  assignment Text :  module_name = "savings_account"
# call node found module_name = "savings_account" assignment
# Node Type :  assignment Text :  module = importlib.import_module(module_name)
# call node found module = importlib.import_module(module_name) assignment
# Node Type :  function_definition Text :  def main():
# ...

# %%
# Python
[
    {
        "source": "savings_account",
        "clause": ["SavingsAccount", "sayWhat", "sayWhy"],
        "file_type": "internal",
        "resolved_path": "/home/user/Documents/Project_5/backend/experiments/data/code/bank_py/savings_account.py",
    },
    {
        "source": "checking_account",
        "clause": ["CheckingAccount as cb"],
        "file_type": "internal",
        "resolved_path": "/home/user/Documents/Project_5/backend/experiments/data/code/bank_py/checking_account.py",
    },
    {"source": "os", "clause": ["mkdir"], "file_type": "stdlib", "resolved_path": None},
    {
        "source": None,
        "clause": ["math as m", "os"],
        "file_type": "stdlib",
        "resolved_path": None,
    },
    {
        "source": None,
        "clause": ["bank_account"],
        "file_type": "internal",
        "resolved_path": "/home/user/Documents/Project_5/backend/experiments/data/code/bank_py/bank_account.py",
    },
    {"source": None, "clause": ["http"], "file_type": "stdlib", "resolved_path": None},
    {
        "source": "fastapi",
        "clause": ["FastAPI"],
        "file_type": "external",
        "resolved_path": None,
    },
]

# %%
# JS
[
    {
        "clause": ["Vehicle", "{DATA}"],
        "source": "./Vehicle.js",
        "file_type": "internal",
        "resolved_path": "/home/user/Documents/Project_5/backend/experiments/data/code/Vehicle_js/Vehicle.js",
    },
    {
        "clause": ["Car"],
        "source": "./Car.js",
        "file_type": "internal",
        "resolved_path": "/home/user/Documents/Project_5/backend/experiments/data/code/Vehicle_js/Car.js",
    },
    {
        "clause": ["ElectricCar"],
        "source": "./ElectricCar.js",
        "file_type": "internal",
        "resolved_path": "/home/user/Documents/Project_5/backend/experiments/data/code/Vehicle_js/ElectricCar.js",
    },
    {
        "clause": ["React"],
        "source": "react",
        "file_type": "external",
        "resolved_path": None,
    },
    {
        "clause": ["fs"],
        "source": "node:fs",
        "file_type": "stdlib",
        "resolved_path": None,
    },
    {
        "source": "./Car.js",
        "file_type": "internal",
        "resolved_path": "/home/user/Documents/Project_5/backend/experiments/data/code/Vehicle_js/Car.js",
        "clause": ["car", "bike"],
    },
]

# %%
# java
{
    "package": "com.example.app",
    "imports": [
        {
            "path": "com.example.vehicle.*",
            "is_static": False,
            "is_wildcard": True,
            "file_type": "internal",
            "resolved_path": "/home/user/Documents/Project_5/backend/experiments/data/code/Vehicle_java/src/com/example/vehicle",
        },
        {
            "path": "com.example.vehicle.Car",
            "is_static": False,
            "is_wildcard": False,
            "file_type": "internal",
            "resolved_path": "/home/user/Documents/Project_5/backend/experiments/data/code/Vehicle_java/src/com/example/vehicle/Car.java",
        },
        {
            "path": "java.lang.Math.PI",
            "is_static": True,
            "is_wildcard": False,
            "file_type": "stdlib",
            "resolved_path": None,
        },
        {
            "path": "java.util.List",
            "is_static": False,
            "is_wildcard": False,
            "file_type": "stdlib",
            "resolved_path": None,
        },
    ],
}

# %%
# go
[
    {"source": "fmt", "alias": None, "file_type": "stdlib", "resolved_path": None},
    {
        "source": "vehicle-project/vehicle",
        "alias": None,
        "file_type": "internal",
        "resolved_path": "/home/user/Documents/Project_5/backend/experiments/data/code/Vehicle_go/vehicle",
    },
    {"source": "math/rand", "alias": "m", "file_type": "stdlib", "resolved_path": None},
    {
        "source": "[github.com/lib/pq](https://github.com/lib/pq)",
        "alias": "_",
        "file_type": "external",
        "resolved_path": None,
    },
    {"source": "net/http", "alias": ".", "file_type": "stdlib", "resolved_path": None},
]
